# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df.shape
# Out:
# (550068, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       376430.000000       166821.000000  550068.000000
# mean             9.842329           12.668243    9263.968713
# std              5.086590            4.125338    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %%
list(df.columns)
# Out:
# ['User_ID',
#  'Product_ID',
#  'Gender',
#  'Age',
#  'Occupation',
#  'City_Category',
#  'Stay_In_Current_City_Years',
#  'Marital_Status',
#  'Product_Category_1',
#  'Product_Category_2',
#  'Product_Category_3',
#  'Purchase']

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
df[[feature for feature in df.columns if df[feature].isnull().sum()>0]].isnull().sum()
# Out:
# Product_Category_2    173638
# Product_Category_3    383247
# dtype: int64

# %%
df[null].isnull().sum()
# Out:
# Product_Category_2    173638
# Product_Category_3    383247
# dtype: int64

# %%
sns.heatmap(df.isnull(),cbar = False )
# Out:
# <AxesSubplot:>

# %%
print(df.columns)
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %% [markdown]
# # Catagorical value to Numeric
# 1) get_dummices
# 2) using map
# 3) factorize

# %%
df.select_dtypes(['object']).columns
# Out:
# Index(['Product_ID', 'Gender', 'Age', 'City_Category',
#        'Stay_In_Current_City_Years'],
#       dtype='object')

# %%
df['Gender'] = df['Gender'].map({'F': 0, 'M':1})

# %%
df.Gender.unique()
# Out:
# array([0, 1])

# %% [markdown]
# # Age handle
# 1) Encoding

# %%
df['Age'].value_counts()
# Out:
# 26-35    219587
# 36-45    110013
# 18-25     99660
# 46-50     45701
# 51-55     38501
# 55+       21504
# 0-17      15102
# Name: Age, dtype: int64

# %%
df['Age'] = df['Age'].map({'0-17': 1, '18-25':2, '26-35':3, '36-45':4, '46-50':5, '51-55': 6, '55+':7})

# %% [markdown]
# from sklearn import preprocessing
# lebel_encoder = preprocessing.LabelEncoder()
# df['Age'] = lebel_encoder.fit_transform(df['Age'])

# %%
df['Age'].value_counts()
# Out:
# 3    219587
# 4    110013
# 2     99660
# 5     45701
# 6     38501
# 7     21504
# 1     15102
# Name: Age, dtype: int64

# %%
df.City_Category.unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
df['City_Category'] = df['City_Category'].map({'A':1,'B':2,'C':3})

# %%
df.City_Category.value_counts()
# Out:
# 2    231173
# 3    171175
# 1    147720
# Name: City_Category, dtype: int64

# %%
df.select_dtypes(['object']).columns
# Out:
# Index(['Product_ID', 'Stay_In_Current_City_Years'], dtype='object')

# %%
df['Stay_In_Current_City_Years'].value_counts()
# Out:
# 1     193821
# 2     101838
# 3      95285
# 4+     84726
# 0      74398
# Name: Stay_In_Current_City_Years, dtype: int64

# %%
df['Product_Category_3'].value_counts()
# Out:
# 16.0    32636
# 15.0    28013
# 14.0    18428
# 17.0    16702
# 5.0     16658
# 8.0     12562
# 9.0     11579
# 12.0     9246
# 13.0     5459
# 6.0      4890
# 18.0     4629
# 4.0      1875
# 11.0     1805
# 10.0     1726
# 3.0       613
# Name: Product_Category_3, dtype: int64

# %%
df['Product_Category_2'].value_counts()
# Out:
# 8.0     64088
# 14.0    55108
# 2.0     49217
# 16.0    43255
# 15.0    37855
# 5.0     26235
# 4.0     25677
# 6.0     16466
# 11.0    14134
# 17.0    13320
# 13.0    10531
# 9.0      5693
# 12.0     5528
# 10.0     3043
# 3.0      2884
# 18.0     2770
# 7.0       626
# Name: Product_Category_2, dtype: int64

# %%
mode2 = df['Product_Category_2'].mode()[0]
print(df['Product_Category_2'].mean())
print(df['Product_Category_2'].median())
# Out:
# 9.842329251122386
# 9.0

# %%
mode3 = df['Product_Category_3'].mode()[0]
print(df['Product_Category_3'].mean())
print(df['Product_Category_3'].median())
# Out:
# 12.668243206790512
# 14.0

# %%
mode3
# Out:
# 16.0

# %%
df['Product_Category_3'] = df['Product_Category_3'].fillna(mode3)
df['Product_Category_2'] = df['Product_Category_3'].fillna(mode2)

# %%
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  int64
#  3   Age                         550068 non-null  int64
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  int64
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          550068 non-null  float64
#  10  Product_Category_3          550068 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(8), object(2)
# ...

# %%
df['Stay_In_Current_City_Years']= df['Stay_In_Current_City_Years'].str.replace('+','')
# Out:
# /tmp/ipykernel_257159/1450051958.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Stay_In_Current_City_Years']= df['Stay_In_Current_City_Years'].str.replace('+','')

# %%
df['Stay_In_Current_City_Years']= df['Stay_In_Current_City_Years'].astype(int)

# %%
df.drop(['User_ID'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Product_ID                  550068 non-null  object
#  1   Gender                      550068 non-null  int64
#  2   Age                         550068 non-null  int64
#  3   Occupation                  550068 non-null  int64
#  4   City_Category               550068 non-null  int64
#  5   Stay_In_Current_City_Years  550068 non-null  int64
#  6   Marital_Status              550068 non-null  int64
#  7   Product_Category_1          550068 non-null  int64
#  8   Product_Category_2          550068 non-null  float64
#  9   Product_Category_3          550068 non-null  float64
#  10  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(8), object(1)
# memory usage: 46.2+ MB

# %%
sns.pairplot(df)
